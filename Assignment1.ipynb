# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'A:\banknifty\GFDLNFO_BACKADJUSTED_03012022.csv')
df.head(10).style.background_gradient(cmap='PuBu').hide_index()
# Out:
# <style type="text/css">
# #T_57b79_row0_col3, #T_57b79_row0_col6, #T_57b79_row7_col7, #T_57b79_row8_col8, #T_57b79_row9_col4, #T_57b79_row9_col5, #T_57b79_row9_col8 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_57b79_row0_col4 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_57b79_row0_col5, #T_57b79_row0_col7, #T_57b79_row2_col7, #T_57b79_row9_col6 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_57b79_row0_col8, #T_57b79_row1_col8, #T_57b79_row4_col5, #T_57b79_row5_col3, #T_57b79_row5_col4, #T_57b79_row5_col7, #T_57b79_row6_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_57b79_row1_col3, #T_57b79_row2_col8, #T_57b79_row3_col8, #T_57b79_row4_col8, #T_57b79_row5_col5, #T_57b79_row6_col5 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_57b79_row1_col4 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_57b79_row1_col5, #T_57b79_row2_col5 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698093 entries, 0 to 698092
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Ticker         698093 non-null  object
#  1   Date           698093 non-null  object
#  2   Time           698093 non-null  object
#  3   Open           698093 non-null  float64
#  4   High           698093 non-null  float64
#  5   Low            698093 non-null  float64
#  6   Close          698093 non-null  float64
#  7   Volume         698093 non-null  int64
#  8   Open Interest  698093 non-null  int64
#  9   Date_Time      698093 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(2), object(3)
# memory usage: 53.3+ MB

# %%
df.isna().sum()
# Out:
# Ticker           0
# Date             0
# Time             0
# Open             0
# High             0
# Low              0
# Close            0
# Volume           0
# Open Interest    0
# Date_Time        0
# dtype: int64

# %%
df.shape
# Out:
# (698093, 10)

# %%
df.describe()
# Out:
#                 Open           High            Low          Close  \
# count  698093.000000  698093.000000  698093.000000  698093.000000
# mean      404.116623     404.859518     403.403306     404.151089
# std      2518.292492    2519.246042    2517.502003    2518.451211
# min         0.050000       0.050000       0.050000       0.050000
# 25%         6.800000       6.850000       6.750000       6.800000
# 50%        25.650000      25.850000      25.500000      25.650000
# 75%       131.250000     131.900000     130.550000     131.200000
# max     74352.850000   74374.700000   74299.950000   74374.700000
#
#              Volume  Open Interest
# count  6.980930e+05   6.980930e+05
# mean   1.037329e+04   2.814561e+06
# std    6.206059e+04   2.030962e+07
# min    1.000000e+01   0.000000e+00
# 25%    4.000000e+02   4.630000e+04
# 50%    1.500000e+03   2.051000e+05
# 75%    5.600000e+03   8.300500e+05
# max    1.043000e+07   7.939400e+08

# %% [markdown]
# # Task 1

# %%
df[df["Ticker"]=="BANKNIFTY-I.NFO"]
# Out:
#                  Ticker        Date      Time      Open      High       Low  \
# 162329  BANKNIFTY-I.NFO  03/01/2022  09:15:59  36621.00  36621.00  35708.05
# 162330  BANKNIFTY-I.NFO  03/01/2022  09:16:59  35813.95  35825.75  35798.70
# 162331  BANKNIFTY-I.NFO  03/01/2022  09:17:59  35796.55  35796.90  35757.40
# 162332  BANKNIFTY-I.NFO  03/01/2022  09:18:59  35782.60  35834.25  35782.60
# 162333  BANKNIFTY-I.NFO  03/01/2022  09:19:59  35830.50  35839.65  35823.40
# ...                 ...         ...       ...       ...       ...       ...
# 162700  BANKNIFTY-I.NFO  03/01/2022  15:26:59  36618.10  36619.95  36608.95
# 162701  BANKNIFTY-I.NFO  03/01/2022  15:27:59  36618.20  36625.00  36617.35
# 162702  BANKNIFTY-I.NFO  03/01/2022  15:28:59  36622.00  36631.85  36618.10
# 162703  BANKNIFTY-I.NFO  03/01/2022  15:29:59  36628.50  36642.00  36624.60
# 162704  BANKNIFTY-I.NFO  03/01/2022  15:30:59  36640.00  36644.00  36640.00
#
#            Close  Volume  Open Interest
# ...

# %%
df
# Out:
#                            Ticker        Date      Time    Open    High  \
# 0       AARTIIND27JAN221000CE.NFO  03/01/2022  09:15:59   38.00   40.05
# 1       AARTIIND27JAN221000CE.NFO  03/01/2022  09:16:59   42.00   42.00
# 2       AARTIIND27JAN221000CE.NFO  03/01/2022  09:17:59   38.05   40.85
# 3       AARTIIND27JAN221000CE.NFO  03/01/2022  09:18:59   41.45   42.50
# 4       AARTIIND27JAN221000CE.NFO  03/01/2022  09:19:59   42.75   43.00
# ...                           ...         ...       ...     ...     ...
# 698088                ZEEL-II.NFO  03/01/2022  15:27:59  325.80  325.80
# 698089                ZEEL-II.NFO  03/01/2022  15:29:59  325.55  325.55
# 698090               ZEEL-III.NFO  03/01/2022  09:32:59  326.50  327.00
# 698091               ZEEL-III.NFO  03/01/2022  11:56:59  327.00  328.15
# 698092               ZEEL-III.NFO  03/01/2022  12:44:59  328.15  328.15
#
#            Low   Close  Volume  Open Interest
# 0        37.00   37.00    5100         212500
# ...

# %%
Step_1=df

# %%
Step_1["Date_Time"]=pd.to_datetime(Step_1['Date'] + ' ' + Step_1['Time'])

# %%
Step_1
# Out:
#                            Ticker        Date      Time    Open    High  \
# 0       AARTIIND27JAN221000CE.NFO  03/01/2022  09:15:59   38.00   40.05
# 1       AARTIIND27JAN221000CE.NFO  03/01/2022  09:16:59   42.00   42.00
# 2       AARTIIND27JAN221000CE.NFO  03/01/2022  09:17:59   38.05   40.85
# 3       AARTIIND27JAN221000CE.NFO  03/01/2022  09:18:59   41.45   42.50
# 4       AARTIIND27JAN221000CE.NFO  03/01/2022  09:19:59   42.75   43.00
# ...                           ...         ...       ...     ...     ...
# 698088                ZEEL-II.NFO  03/01/2022  15:27:59  325.80  325.80
# 698089                ZEEL-II.NFO  03/01/2022  15:29:59  325.55  325.55
# 698090               ZEEL-III.NFO  03/01/2022  09:32:59  326.50  327.00
# 698091               ZEEL-III.NFO  03/01/2022  11:56:59  327.00  328.15
# 698092               ZEEL-III.NFO  03/01/2022  12:44:59  328.15  328.15
#
#            Low   Close  Volume  Open Interest           Date_Time
# ...

# %%
Step_1.dtypes
# Out:
# Ticker                   object
# Date                     object
# Time                     object
# Open                    float64
# High                    float64
# Low                     float64
# Close                   float64
# Volume                    int64
# Open Interest             int64
# Date_Time        datetime64[ns]
# dtype: object

# %%
Droping_Data=Step_1.drop(['Ticker','Date','Time','Volume','Open Interest'],axis=1)

# %%
Droping_Data.sort_values(by='Date_Time',ascending = False, inplace = True) 
Droping_Data
# Out:
#            Open     High      Low    Close           Date_Time
# 288100    37.50    37.50    37.50    37.50 2022-03-01 15:30:59
# 46089      2.75     2.75     2.75     2.75 2022-03-01 15:30:59
# 154379   771.60   771.60   771.60   771.60 2022-03-01 15:30:59
# 2712       6.20     6.20     6.20     6.20 2022-03-01 15:30:59
# 205916     0.90     0.90     0.90     0.90 2022-03-01 15:30:59
# ...         ...      ...      ...      ...                 ...
# 123840   614.00   626.00   614.00   615.25 2022-03-01 09:15:59
# 418080    78.00    78.00    78.00    78.00 2022-03-01 09:15:59
# 671745  3283.75  3298.00  3283.75  3298.00 2022-03-01 09:15:59
# 41356     28.65    28.65    28.60    28.60 2022-03-01 09:15:59
# 0         38.00    40.05    37.00    37.00 2022-03-01 09:15:59
#
# [698093 rows x 5 columns]

# %% [markdown]
# # Task 2

# %%
df
# Out:
#                            Ticker        Date      Time    Open    High  \
# 0       AARTIIND27JAN221000CE.NFO  03/01/2022  09:15:59   38.00   40.05
# 1       AARTIIND27JAN221000CE.NFO  03/01/2022  09:16:59   42.00   42.00
# 2       AARTIIND27JAN221000CE.NFO  03/01/2022  09:17:59   38.05   40.85
# 3       AARTIIND27JAN221000CE.NFO  03/01/2022  09:18:59   41.45   42.50
# 4       AARTIIND27JAN221000CE.NFO  03/01/2022  09:19:59   42.75   43.00
# ...                           ...         ...       ...     ...     ...
# 698088                ZEEL-II.NFO  03/01/2022  15:27:59  325.80  325.80
# 698089                ZEEL-II.NFO  03/01/2022  15:29:59  325.55  325.55
# 698090               ZEEL-III.NFO  03/01/2022  09:32:59  326.50  327.00
# 698091               ZEEL-III.NFO  03/01/2022  11:56:59  327.00  328.15
# 698092               ZEEL-III.NFO  03/01/2022  12:44:59  328.15  328.15
#
#            Low   Close  Volume  Open Interest           Date_Time
# ...

# %%
Z=df

# %%
Z= Z[Z['Ticker'].astype(str).str.contains('BANKNIFTY')]
Z
# Out:
#                              Ticker        Date      Time      Open      High  \
# 70634   BANKNIFTY03FEB2235000PE.NFO  03/01/2022  13:50:59    446.10    446.10
# 70635   BANKNIFTY03FEB2235500CE.NFO  03/01/2022  09:26:59   1236.60   1236.60
# 70636   BANKNIFTY03FEB2235500CE.NFO  03/01/2022  09:27:59   1236.60   1236.60
# 70637   BANKNIFTY03FEB2235500CE.NFO  03/01/2022  09:30:59   1236.60   1236.60
# 70638   BANKNIFTY03FEB2235500CE.NFO  03/01/2022  11:59:59   1325.45   1325.45
# ...                             ...         ...       ...       ...       ...
# 163303            BANKNIFTY-III.NFO  03/01/2022  15:26:59  36898.00  36900.00
# 163304            BANKNIFTY-III.NFO  03/01/2022  15:27:59  36900.00  36902.20
# 163305            BANKNIFTY-III.NFO  03/01/2022  15:28:59  36911.00  36913.40
# 163306            BANKNIFTY-III.NFO  03/01/2022  15:29:59  36912.00  36912.95
# 163307            BANKNIFTY-III.NFO  03/01/2022  15:30:59  36910.00  36910.00
#
# ...

# %%
Z.drop(Z[Z["Ticker"].str.contains("BANKNIFTY-I.NFO")].index,inplace=True)
Z.drop(Z[Z["Ticker"].str.contains("BANKNIFTY-II.NFO")].index,inplace=True)
Z.drop(Z[Z["Ticker"].str.contains("BANKNIFTY-III.NFO")].index,inplace=True)
# Out:
# C:\Users\Manis\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
Z
# Out:
#                              Ticker        Date      Time     Open     High  \
# 70634   BANKNIFTY03FEB2235000PE.NFO  03/01/2022  13:50:59   446.10   446.10
# 70635   BANKNIFTY03FEB2235500CE.NFO  03/01/2022  09:26:59  1236.60  1236.60
# 70636   BANKNIFTY03FEB2235500CE.NFO  03/01/2022  09:27:59  1236.60  1236.60
# 70637   BANKNIFTY03FEB2235500CE.NFO  03/01/2022  09:30:59  1236.60  1236.60
# 70638   BANKNIFTY03FEB2235500CE.NFO  03/01/2022  11:59:59  1325.45  1325.45
# ...                             ...         ...       ...      ...      ...
# 162324  BANKNIFTY31MAR2242000CE.NFO  03/01/2022  14:40:59   224.65   224.65
# 162325  BANKNIFTY31MAR2242000CE.NFO  03/01/2022  14:55:59   225.45   225.45
# 162326  BANKNIFTY31MAR2242000CE.NFO  03/01/2022  15:26:59   210.00   210.00
# 162327  BANKNIFTY31MAR2243500CE.NFO  03/01/2022  14:43:59    80.00    80.00
# 162328  BANKNIFTY31MAR2243500CE.NFO  03/01/2022  14:51:59    90.50    90.50
#
# ...

# %%
Z["Expiry"]=Z["Ticker"].str[9:16]
Z["Scrip"]=Z["Ticker"].str[16:23]
Z
# Out:
# C:\Users\Manis\AppData\Local\Temp/ipykernel_24196/3350906780.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z["Expiry"]=Z["Ticker"].str[9:16]
# C:\Users\Manis\AppData\Local\Temp/ipykernel_24196/3350906780.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z["Scrip"]=Z["Ticker"].str[16:23]
#                              Ticker        Date      Time     Open     High  \
# 70634   BANKNIFTY03FEB2235000PE.NFO  03/01/2022  13:50:59   446.10   446.10
# ...

# %%
New_data=Z

# %%
New_data['Expiry'] = pd.to_datetime(New_data['Expiry'])
New_data
# Out:
# C:\Users\Manis\AppData\Local\Temp/ipykernel_24196/4242155901.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   New_data['Expiry'] = pd.to_datetime(New_data['Expiry'])
#                              Ticker        Date      Time     Open     High  \
# 70634   BANKNIFTY03FEB2235000PE.NFO  03/01/2022  13:50:59   446.10   446.10
# 70635   BANKNIFTY03FEB2235500CE.NFO  03/01/2022  09:26:59  1236.60  1236.60
# 70636   BANKNIFTY03FEB2235500CE.NFO  03/01/2022  09:27:59  1236.60  1236.60
# 70637   BANKNIFTY03FEB2235500CE.NFO  03/01/2022  09:30:59  1236.60  1236.60
# 70638   BANKNIFTY03FEB2235500CE.NFO  03/01/2022  11:59:59  1325.45  1325.45
# ...                             ...         ...       ...      ...      ...
# ...

# %%
New_data["Date_Time"]=pd.to_datetime(New_data['Date'] + ' ' + New_data['Time'])
New_data
# Out:
# C:\Users\Manis\AppData\Local\Temp/ipykernel_24196/1020947051.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   New_data["Date_Time"]=pd.to_datetime(New_data['Date'] + ' ' + New_data['Time'])
#                              Ticker        Date      Time     Open     High  \
# 70634   BANKNIFTY03FEB2235000PE.NFO  03/01/2022  13:50:59   446.10   446.10
# 70635   BANKNIFTY03FEB2235500CE.NFO  03/01/2022  09:26:59  1236.60  1236.60
# 70636   BANKNIFTY03FEB2235500CE.NFO  03/01/2022  09:27:59  1236.60  1236.60
# 70637   BANKNIFTY03FEB2235500CE.NFO  03/01/2022  09:30:59  1236.60  1236.60
# 70638   BANKNIFTY03FEB2235500CE.NFO  03/01/2022  11:59:59  1325.45  1325.45
# ...                             ...         ...       ...      ...      ...
# ...

# %%
New_data.dtypes
# Out:
# Ticker                   object
# Date                     object
# Time                     object
# Open                    float64
# High                    float64
# Low                     float64
# Close                   float64
# Volume                    int64
# Open Interest             int64
# Date_Time        datetime64[ns]
# Expiry           datetime64[ns]
# Scrip                    object
# dtype: object

# %%
New_data['Date']=pd.to_datetime(New_data['Date'])
# Out:
# C:\Users\Manis\AppData\Local\Temp/ipykernel_24196/2862583816.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   New_data['Date']=pd.to_datetime(New_data['Date'])

# %%
New_data["DTE"]=New_data['Expiry'] - New_data['Date']
# Out:
# C:\Users\Manis\AppData\Local\Temp/ipykernel_24196/2522992358.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   New_data["DTE"]=New_data['Expiry'] - New_data['Date']

# %%
New_data['DTE']=New_data['DTE'].dt.days

# %%
New_data.sort_values(by='DTE',ascending = True, inplace = True) 
New_data
# Out:
#                              Ticker       Date      Time     Open     High  \
# 97021   BANKNIFTY06JAN2236300PE.NFO 2022-03-01  15:18:59   244.30   245.00
# 70673   BANKNIFTY06JAN2230400PE.NFO 2022-03-01  09:34:59     2.55     2.60
# 70691   BANKNIFTY06JAN2230400PE.NFO 2022-03-01  09:52:59     2.85     3.00
# 70672   BANKNIFTY06JAN2230400PE.NFO 2022-03-01  09:33:59     2.60     2.60
# 70670   BANKNIFTY06JAN2230400PE.NFO 2022-03-01  09:31:59     2.60     2.60
# ...                             ...        ...       ...      ...      ...
# 162326  BANKNIFTY31MAR2242000CE.NFO 2022-03-01  15:26:59   210.00   210.00
# 162248  BANKNIFTY31MAR2236000PE.NFO 2022-03-01  12:54:59  1252.00  1252.00
# 162320  BANKNIFTY31MAR2242000CE.NFO 2022-03-01  13:56:59   186.05   186.05
# 162317  BANKNIFTY31MAR2242000CE.NFO 2022-03-01  13:29:59   174.60   174.60
# 162328  BANKNIFTY31MAR2243500CE.NFO 2022-03-01  14:51:59    90.50    90.50
#
# ...

# %%
Droping_Data_1=New_data.drop(['Ticker','Date','Time','Volume','Open Interest'],axis=1)
Droping_Data_1
# Out:
#            Open     High      Low    Close           Date_Time     Expiry  \
# 97021    244.30   245.00   230.40   230.80 2022-03-01 15:18:59 2022-01-06
# 70673      2.55     2.60     2.55     2.55 2022-03-01 09:34:59 2022-01-06
# 70691      2.85     3.00     2.75     2.95 2022-03-01 09:52:59 2022-01-06
# 70672      2.60     2.60     2.55     2.55 2022-03-01 09:33:59 2022-01-06
# 70670      2.60     2.60     2.55     2.55 2022-03-01 09:31:59 2022-01-06
# ...         ...      ...      ...      ...                 ...        ...
# 162326   210.00   210.00   210.00   210.00 2022-03-01 15:26:59 2022-03-31
# 162248  1252.00  1252.00  1252.00  1252.00 2022-03-01 12:54:59 2022-03-31
# 162320   186.05   186.05   186.05   186.05 2022-03-01 13:56:59 2022-03-31
# 162317   174.60   174.60   174.60   174.60 2022-03-01 13:29:59 2022-03-31
# 162328    90.50    90.50    90.50    90.50 2022-03-01 14:51:59 2022-03-31
#
#           Scrip  DTE
# 97021   36300PE  -54
# 70673   30400PE  -54
# ...

# %%
Droping_Data_1.sort_values(by='Date_Time',ascending = False, inplace = True) 
Droping_Data_1
# Out:
#            Open     High      Low    Close           Date_Time     Expiry  \
# 145709   265.20   265.20   265.20   265.20 2022-03-01 15:30:59 2022-01-27
# 140833    67.00    67.00    67.00    67.00 2022-03-01 15:30:59 2022-01-27
# 155872   968.00   968.00   968.00   968.00 2022-03-01 15:30:59 2022-01-27
# 139336    23.45    23.45    23.45    23.45 2022-03-01 15:30:59 2022-01-27
# 162213   357.95   357.95   357.95   357.95 2022-03-01 15:30:59 2022-03-31
# ...         ...      ...      ...      ...                 ...        ...
# 135351  1729.95  1790.00  1729.95  1790.00 2022-03-01 09:15:59 2022-02-24
# 105375     6.90     6.90     4.35     4.75 2022-03-01 09:15:59 2022-01-06
# 134670   340.05   340.05   340.05   340.05 2022-03-01 09:15:59 2022-02-24
# 117804   198.00   198.00   198.00   198.00 2022-03-01 09:15:59 2022-01-13
# 105750     4.40     4.40     3.95     4.05 2022-03-01 09:15:59 2022-01-06
#
#           Scrip  DTE
# 145709  35000PE  -33
# 140833  33000PE  -33
# ...
